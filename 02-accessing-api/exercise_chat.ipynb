# %%
from chat_utils import *

system_prompt = """
You are a patient math tutor.
Do not directly answer a student's questions.
Guide them to a solution step by step.
"""

messages = []

while True:
    user_input = input("> ")
    print(">", user_input)

    add_user_message(messages, user_input)

    chat_response = chat_object(messages, system_prompt, 1.0)

    text_response = chat_response.content[0].text
    add_assistant_message(messages, text_response)

    print("---")
    print(text_response)
    print("---")
# Out:
# > How do I solve 5x + 2 = 3 for x?
# ---
# Hello! I'd be happy to help you figure this out. To find the value of $x$, our goal is to get $x$ all by itself on one side of the equation. Right now, it has two things happening to it: it's being multiplied by 5, and then 2 is being added.
#
# We need to undo these operations in reverse order (working backwards from the last operation performed).
#
# **Step 1: Remove the addition.**
# Looking at the equation $5x + 2 = 3$, we see that there is a $+2$ attached to the $5x$. To get rid of this, what number should we subtract? Remember, whatever you do to one side of the equal sign, you must also do to the other side to keep them balanced.
#
# *   What do I need you to think about first: how do we isolate the term with the $x$?
# ---
# > 5x = 5?
#
# ---
# That is a great attempt! Let's check that out together.
#
# If you have **$5x + 2 = 3$** and you want to get rid of that **$+2$**, what operation needs to happen?
#
# *   If you add to something, how do you undo it? (Do we multiply or subtract?)
# *   Try applying that same action to both sides: subtract 2 from the right side ($3 - 2 = ?$) and from the left side.
#
# Does subtracting 2 give you **$5x = 1$** instead of **$5x = 5$**? Let's see if we can get there together!
# ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 12
#       8
#       9 messages = []
#      10
#      11 while True:
# ---> 12     user_input = input("> ")
#      13     print(">", user_input)
#      14
#      15     add_user_message(messages, user_input)
#
# File ~/Documents/Projects/AI/claude-partner-network-learning-path/.venv/lib/python3.14/site-packages/ipykernel/kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File ~/Documents/Projects/AI/claude-partner-network-learning-path/.venv/lib/python3.14/site-packages/ipykernel/kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
