# %%
from chat_utils import *

# %%
system_prompt = """
Do not include comments, use meaningful names for variables.
Respond with one solution.
"""

system_prompt = """
You are a Python engineer who writes very concise code
"""

messages = []

add_user_message(messages, "Write a Python function that checks a string for deplicate characters.")

chat_response = chat_object(messages, system_prompt, 1)

text_response = chat_response.content[0].text
add_assistant_message(messages, text_response)

print("---")
print(text_response)
print("---")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 12
#       8 """
#       9
#      10 messages = []
#      11
# ---> 12 add_user_message(messages, "Write a Python function that checks a string for deplicate characters.")
#      13
#      14 chat_response = chat_object(messages, system_prompt, 1)
#      15
#
# NameError: name 'add_user_message' is not defined

# %%
 messages = []

add_user_message(messages, "Generate a one sentence movie idea")

text_response = chat_message(messages, temperature=0.0)
print("---")
print(text_response)
print("---")

text_response = chat_message(messages, temperature=0.5)
print("---")
print(text_response)
print("---")

text_response = chat_message(messages, temperature=1.0)
print("---")
print(text_response)
print("---")
# Out:
# ---
# A retired clockmaker discovers that every time he winds his pocket watch, it rewinds reality by exactly one hour, forcing him to relive the day of his wife's fatal accident until he can find a way to change it without erasing himself.
# ---
# ---
# In a world where memories can be traded like currency, a struggling archivist discovers a forbidden memory that reveals the entire city is actually an elaborate simulation designed to hide a cosmic horror.
# ---
# ---
# A retired clockmaker discovers he has the rare ability to hear the specific time of day each person died, leading him on a desperate race through a city filled with ticking clocks and hidden secrets.
# ---

# %%
def has_duplicate_characters(text: str) -> bool:
    return len(set(text)) != len(text)


print(has_duplicate_characters("a;sdlfj"))
print(has_duplicate_characters("a;sdlfsj"))
# Out:
# False
# True
