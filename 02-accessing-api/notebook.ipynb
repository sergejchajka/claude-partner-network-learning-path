# %%
from chat_utils import *

# %%
from anthropic.types import MessageParam

from agents.lm_studio_local import create_local_chat_model

client = create_local_chat_model()

# %%
messages: list[MessageParam] = []

# %%
add_user_message(messages, "What is quantum computing? Answer in one sentence")
response1 = chat_object(messages)
add_assistant_message(messages, response1.content[0].text)

# %%
add_user_message(messages, "Write another sentence")
response2 = chat_object(messages)
add_assistant_message(messages, response1.content[0].text)

# %%
messages = []
add_user_message(messages, "What is quantum computing?")
stream = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=messages,
    stream=True,
)

for chunk in stream:
    print(chunk)

# RawMessageStartEvent(message=Message(id='msg_agagik4x5mf74fb5iz2nsf', container=None, content=[], model='qwen/qwen3.5-9b', role='assistant', stop_details=None, stop_reason=None, stop_sequence=None, type='message', usage=Usage(cache_creation=None, cache_creation_input_tokens=None, cache_read_input_tokens=0, inference_geo=None, input_tokens=17, output_tokens=0, output_tokens_details=None, server_tool_use=None, service_tier=None)), type='message_start')
#  (content_block=TextBlock(citations=None, text='', type='text'), index=0, type='content_block_start')
# RawContentBlockDeltaEvent(delta=TextDelta(text='**', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text='.', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockStopEvent(index=0, type='content_block_stop')
# RawMessageDeltaEvent(delta=Delta(container=None, stop_details=None, stop_reason='end_turn', stop_sequence=None), type='message_delta', usage=MessageDeltaUsage(cache_creation_input_tokens=None, cache_read_input_tokens=0, input_tokens=17, output_tokens=770, output_tokens_details=None, server_tool_use=None))
# RawMessageStopEvent(type='message_stop')
# Out:
# RawMessageStartEvent(message=Message(id='msg_agagik4x5mf74fb5iz2nsf', container=None, content=[], model='qwen/qwen3.5-9b', role='assistant', stop_details=None, stop_reason=None, stop_sequence=None, type='message', usage=Usage(cache_creation=None, cache_creation_input_tokens=None, cache_read_input_tokens=0, inference_geo=None, input_tokens=17, output_tokens=0, output_tokens_details=None, server_tool_use=None, service_tier=None)), type='message_start')
# RawContentBlockStartEvent(content_block=TextBlock(citations=None, text='', type='text'), index=0, type='content_block_start')
# RawContentBlockDeltaEvent(delta=TextDelta(text='**', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text='Quant', type='text_delta'), index=0, type='content_block_delta')
# RawContentBlockDeltaEvent(delta=TextDelta(text='um', type='text_delta'), index=0, type='content_block_delta')
# ...

# %%
messages = []
add_user_message(messages, "What is quantum computing? Answer in one sentence")
with client.messages.stream(
    model=model ,
    max_tokens=1000,
    messages=messages,
) as stream:
    for chunk in stream.text_stream :
        print(chunk, end="")

final_message = stream.get_final_message()
# Out:
# Quantum computing is a type of computation that harnesses the principles of quantum mechanics, such as superposition and entanglement, to perform certain calculations at speeds vastly exceeding those of classical computers.

# %%
messages = []
add_user_message(messages, "Generate a very short event bridge rule as json")
add_assistant_message(messages, "```json")
response = chat_message(messages, stop_sequences=["```"])

import json

print(response)
json_data = json.loads(response.strip())
print(json_data)
# Out:
# {
#   "id": "example-rule-1",
#   "name": "Test Event Rule",
#   "description": "A simple example rule",
#   "enabled": true,
#   "eventBusArn": "arn:aws:eventbus:region:account-id:bus/my-bus",
#   "pattern": {
#     "source": ["my-app"],
#     "detail-type": ["My Event Type"]
#   },
#   "targets": [
#     {
#       "id": "1",
#       "arn": "arn:aws:lambda:region:account-id:function:my-lambda-function",
#       "deadLetterConfig": {
#         "arn": "arn:aws:sqs:region:account-id:dlq"
#       },
#       "roleArn": "arn:aws:iam::account-id:role/lambda-execution-role"
#     }
#   ]
# }
#
# ...

# %%
messages = []

prompt = """
Generate three different sample AWS CLI commands. Each should be very short
"""

add_user_message(messages, prompt)
add_assistant_message(messages, "Here are all three different sample AWS CLI commands in a single block without comments, one per line:\n```bash")

response = chat_message(messages, stop_sequences=["```"])

print(response)
# Out:
# aws ec2 describe-instances --filters "Name=state,name=value" "Value=running"
# aws s3 ls s3://my-bucket-name/
# aws iam create-user --user-name newuser --password Password123!@#
